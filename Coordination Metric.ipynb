# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
d_davg_a = np.linspace(0, 2.718, 1000)
n_a = [2, 4, 6, 8, 10]
for n in n_a:
    
    w_a = np.exp(1 - (d_davg_a)**n)

    plt.plot(d_davg_a, w_a, '-')
    
plt.legend(n_a)    
plt.xlabel('shell distance')
plt.ylabel('coordination weight')

# %%
ds_a = [1, 1, 1, 1.4, 1.6, 2, 2.2]
davg = ds_a[0]
for dist in ds_a:
    w_a = np.exp(1 - (d_davg_a)**n)
    davg = (sum(w_a * ds_a))/(sum(w_a))
# Out:
# (8,)

# %%
not_converged = True
while not_converged:
    w_a = np.exp(1 - (ds_a / davg_new))
    
    TOL = 1e-4
    np.abs(davg_new - davg) > TOL
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ffde831b6f6c> in <module>()
#       1 not_converged = True
#       2 while not_converged:
# ----> 3     w_a = np.exp(1 - (ds_a / davg_new))
#       4
#       5     TOL = 1e-4
#
# NameError: name 'np' is not defined

# %%
np.ndarray?
